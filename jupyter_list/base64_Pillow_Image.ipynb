# %%
import base64
from PIL import Image
import io

# %%
# buffer = io.BytesIO()


  
  
with open("/Users/ewan/Desktop/dev/test_mango/temp/temporary.png", "rb") as buff:
    converted_string = base64.b64encode(buff.read())
print(converted_string)
  
with open('/Users/ewan/Desktop/dev/test_mango/temp/encode.txt', "wb") as file:
    file.write(converted_string)
# Out:
# b'...'
