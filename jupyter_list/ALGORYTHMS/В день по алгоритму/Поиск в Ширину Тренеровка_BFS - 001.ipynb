# %%
# Поиск в ширину:

# %%
from collections import deque

keys1 = [ f"{i} {'abcdefjh'.index(i)}" for i in 'abcdefjh' ]
vals1 = [ y for y in range(len(keys1))]

dict1 = {k:v for k,v in zip(keys1,vals1)}
