# %%
# 1. Символы и квантификаторы
# Паттерн	Значение	Пример
# .	любой символ (кроме \n)	a.b → acb, arb
# ^	начало строки	^Hello — ищет строки, начинающиеся с Hello
# $	конец строки	world$ — ищет строки, оканчивающиеся на world
# *	0 или более повторов	ab* → a, ab, abb
# +	1 или более повторов	ab+ → ab, abb
# ?	0 или 1 повтор	colou?r → color, colour
# {n}	ровно n повторов	\d{4} → 2025
# {n,}	минимум n повторов	\d{2,} → 12, 12345
# {n,m}	от n до m повторов	\d{2,4} → 12, 1234

# 2. Множества символов
# Паттерн	Значение
# [abc]	любой символ из списка
# [^abc]	любой символ, кроме перечисленных
# [a-z]	любой символ от a до z
# [A-Za-z0-9_]	буквы и цифры
# \d	цифра (0–9)
# \D	не цифра
# \w	буква, цифра или _
# \W	всё, кроме \w
# \s	пробел, табуляция, перенос
# \S	всё, кроме пробельных символов

# 3. Группировка и альтернативы
# Паттерн	Значение
# (abc)	группа (запоминает совпадение)
# (?:abc)	группа без запоминания
# `a	b`
# (?P<name>...)	именованная группа
# \1, \2	ссылка на предыдущие группы

# 4. Ленивая (lazy) и жадная (greedy) выборка
# Паттерн	Значение
# .*	жадный — захватывает всё
# .*?	ленивый — минимальный захват
# .+?	ленивый, 1+ символов

# 5. Спецконструкции
# Паттерн	Значение
# (?=...)	позитивный lookahead (перед чем-то)
# (?!...)	негативный lookahead (не перед чем-то)
# (?<=...)	позитивный lookbehind (после чего-то)
# (?<!...)	негативный lookbehind
# (?#комментарий)	комментарий
# (?i)	флаг: регистронезависимый поиск
# (?m)	флаг: многострочный режим
# (?s)	флаг: . включает \n

# %%
str1 = 'ABCD'
str2 = '1234'

wrd = 'Alpho Betha Control Doo'
de = 't'

tbl = wrd.maketrans(str1,str2,de)

wrd.translate(tbl)
# Out:
# '1lpho 2eha 3onrol 4oo'

# %%
# Специальные символы,
# '.' - любой символ;
# '^' - началу строки;
# '$' - конец строки;
# '*' - 0 или более повторений;
# '+' - 1 или более повторений;
# '?' - 0 или 1 повторений;
# '*?', '+?','??' - ограничение жадности;
# '*+', '++', '?+' - притяжательные квантификаторы, (новое в Python 3.11);
# '{m}' - m повторений;
# '{m,n}' - как можно больше повторений в промежутке от m до n ;
# '{m,n}?' - как можно меньше повторений в промежутке от m до n;
# '{m,n}+' - притяжательная версия квантификатора выше, (новое в Python 3.11);
# '\' - экранирование специальных символов;
# '[]' - символьный класс;
# '|' - или;
# '(...)' - группа с захватом;

# %%
# Флаги, используемые в функции re.compile()
# Функция search() модуля re
# Функция match() модуля re
# Функция fullmatch() модуля re
# Функция finditer() модуля re
# Функция split() модуля re
# Функция findall() модуля re
# Функция sub() модуля re
# Функция subn() модуля re
# Функция escape() модуля re
# Функция purge() модуля re
# Исключение error() модуля re
# Объект регулярного выражения Pattern модуля re
# Объект совпадения с шаблоном Match модуля re

# %%
import re 

body = "Например это будет 5 тут будет 12 а тут будет 77 а еще куча цифр будет которые надо отловить в итере 90998765434567((0-09876"

match = re.finditer(r'\d+',body) # \d - any num - + more then 1


# match.start() - match.end() - match.group() 
res =  [ i.group() for i in match ]  #[ f"Strat is:{i.start()} -- End is: {i.end()} -- The match is: {i.group()}" for i in match ]



res
# Out:
# ['5', '12', '77', '90998765434567', '0', '09876']

# %%
import re 

body = """<?xml version='1.0' encoding='utf-8' standalone='yes' ?>
<map>
    <int name="cam10_port_rtsp" value="195" />
    <string name="cam16_password">TG9nb3M4ODg4OA==</string>
    <string name="preference_cam27_hostname">92.253.235.246</string>
    <string name="preference_cam30_hostname">192.168.8.241</string>
    <string name="preference_cam30_remote_hostname">92.253.235.246</string>
    <boolean name="cam18_md_oc" value="false" />
    <int name="cam31_id" value="1833939066" />
    <int name="preference_cam31_port" value="198" />
    <string name="preference_cam21_model">DH-SD59225U-HNI</string>
    <string name="cam13_username">YWRtaW4=</string>
    <string name="preference_cam16_vendor">Dahua</string>
    <string name="preference_cam35_hostname">92.253.235.246</string>
    <string name="preference_cam5_model">DH-SD59225U-HNI</string>
    <string name="preference_cam34_model">DH-SD59225U-HNI</string>
    <string name="preference_cam12_vendor">Dahua</string>
    <int name="cam32_protocol" value="3" />
    <int name="cam6_port_rtsp" value="155" />
    <string name="preference_cam3_name">Гараж основной вид в сторону дома</string>
    <int name="cam2_id" value="1062279322" />
    <int name="cam2_protocol" value="3" />
    <int name="cam34_remote_port_rtsp" value="31554" />
    <string name="preference_cam16_name">Улица вид на лестницу около генератора </string>
    <string name="cam18_md_ia_mask3">1ff,1ff,1ff,1ff,1ff,1ff,1ff,1ff,1fe,1f1,101,100,101,101,101,1ff</string>
    <int name="cam19_id" value="1177695698" />
    <int name="cam7_protocol" value="3" />
    <string name="preference_cam13_model">DH-SD59225U-HNI</string>
    <string name="preference_cam19_hostname">192.168.8.164</string>
    <string name="preference_cam22_hostname">92.253.235.246</string>
    <string name="cam21_tags"></string>
    <int name="cam3_id" value="735361441" />
    <string name="preference_cam21_remote_hostname">92.253.235.246</string>
    <string name="preference_cam1_vendor">Dahua</string>
    <string name="cam25_username">YWRtaW4=</string>
    <string name="cam6_password">YWRtbG9nb3M4</string>
    <string name="preference_cam4_hostname">92.253.235.246</string>
    <string name="cam24_password">YWRtbG9nb3M4</string>
    <int name="cam12_protocol" value="3" />
    <int name="preference_cam26_port" value="197" />
    <string name="cam30_tags"></string>
    <string name="cam33_tags"></string>
    <string name="preference_cam12_remote_hostname">92.253.235.246</string>
    <int name="preference_cam18_audio_alarm" value="7" />
    <int name="cam20_id" value="429531687" />
    <string name="cam29_password">YWRtbG9nb3M4</string>
    <string name="preference_cam9_hostname">92.253.235.246</string>
    <string name="preference_cam15_remote_hostname">92.253.235.246</string>
    <string name="preference_cam18_remote_hostname">212.233.87.20</string>
    <int name="cam17_protocol" value="3" />
    <string name="preference_cam14_hostname">192.168.8.230</string>
    <string name="preference_cam33_name">Котельная</string>
    <string name="cam33_username">YWRtaW4=</string>
    <int name="cam8_port_rtsp" value="115" />
    <string name="cam11_password">YWRtbG9nb3M4</string>
    <string name="cam3_tags"></string>
    <int name="cam16_protocol" value="3" />
    <string name="cam29_tags"></string>
    <int name="cam21_id" value="888860267" />
    <string name="preference_cam18_model">DH-SD59225U-HNI</string>
    <int name="cam21_port_rtsp" value="136" />
    <int name="cam28_port_rtsp" value="203" />
    <string name="preference_cam15_hostname">92.253.235.246</string>
    <int name="cam19_remote_port_rtsp" value="20554" />
    <int name="cam4_port_rtsp" value="214" />
    <int name="cam1_id" value="1471734556" />
    <int name="preference_cam5_port" value="206" />
    <string name="cam7_password">YWRtbG9nb3M4</string>
    <string name="preference_cam9_vendor">Dahua</string>
    <string name="preference_cam30_vendor">Dahua</string>
    <string name="preference_cam27_vendor">Dahua</string>
    <string name="preference_cam34_hostname">92.253.235.246</string>
    <string name="preference_cam5_hostname">92.253.235.246</string>
    <string name="cam31_password">YWRtbG9nb3M4</string>
    <int name="cam29_remote_port_rtsp" value="28554" />
    <int name="cam25_protocol" value="3" />
    <int name="cam32_id" value="2113410988" />
    <int name="preference_cam10_port" value="195" />
    <string name="preference_cam24_name">Кабинет в фоке</string>
    <string name="cam12_username">YWRtaW4=</string>
    <string name="cam12_tags"></string>
    <int name="preference_cam35_port" value="220" />
    <string name="cam18_username">YWRtaW4=</string>
    <string name="cam15_password">TG9nb3M4ODg4OA==</string>
    <string name="cam12_password">YWRtbG9nb3M4</string>
    <string name="cam34_username">YWRtaW4=</string>
    <int name="cam33_id" value="2007030537" />
    <int name="cam10_id" value="1458717482" />
    <string name="cam13_tags"></string>
    <int name="preference_cam34_port" value="225" />
    <string name="preference_cam6_vendor">Dahua</string>
    <string name="preference_cam24_vendor">Dahua</string>
    <int name="cam29_protocol" value="3" />
    <string name="preference_cam35_vendor">Dahua</string>
    <string name="preference_cam25_name">Мал.студия в фоке</string>
    <string name="cam22_tags"></string>
    <int name="cam35_port_rtsp" value="220" />
    <string name="preference_cam13_vendor">Dahua</string>
    <string name="cam28_tags"></string>
    <string name="cam21_username">YWRtaW4=</string>
    <string name="preference_cam0_model">DH-SD59225U-HNI</string>
    <boolean name="preference_cam0_audio_receive_on_startup" value="true" />
    <int name="preference_cam4_port" value="214" />
    <string name="cam3_username">YWRtaW4=</string>
    <string name="preference_cam15_model">DH-SD59230S-HN</string>
    <boolean name="preference_cam2_audio_receive_on_startup" value="true" />
    <string name="preference_cam8_hostname">92.253.235.246</string>
    <string name="cam28_password">YWRtbG9nb3M4</string>
    <string name="preference_cam19_remote_hostname">92.253.235.246</string>
    <int name="preference_cam15_port" value="243" />
    <string name="cam5_password">YWRtbG9nb3M4</string>
    <int name="cam33_port_rtsp" value="196" />
    <string name="preference_cam29_name">Фок вход в спортзал</string>
    <string name="preference_cam18_hostname">92.253.235.246</string>
    <int name="cam8_protocol" value="3" />
    <int name="cam11_remote_port_rtsp" value="226" />
    <string name="preference_cam31_model">DH-SD59225U-HNI</string>
    <int name="cam5_id" value="1419128152" />
    <string name="preference_cam21_hostname">92.253.235.246</string>
    <int name="cam17_port_rtsp" value="163" />
    <string name="cam24_tags"></string>
    <int name="preference_cam2_port" value="150" />
    <string name="preference_cam29_model">DH-SD59225U-HNI</string>
    <int name="cam22_id" value="2130565046" />
    <int name="cam18_port_rtsp" value="212" />
    <int name="preference_cam18_remote_port" value="212" />
    <int name="cam11_id" value="1951648643" />
    <int name="cam31_protocol" value="3" />
    <string name="cam25_password">YWRtbG9nb3M4</string>
    <string name="preference_cam17_model">DH-SD59225U-HNI</string>
    <string name="preference_cam16_remote_hostname">92.253.235.246</string>
    <int name="preference_cam13_port" value="239" />
    <string name="preference_cam27_name">Майнерная 2 этаж цод</string>
    <string name="cam29_username">YWRtaW4=</string>
    <int name="cam21_remote_port_rtsp" value="136" />
    <string name="preference_cam32_name">тех.помещение джакузи бассейна</string>
    <int name="cam23_id" value="1232976204" />
    <string name="preference_cam23_model">DH-SD59225U-HNI</string>
    <string name="preference_cam16_hostname">92.253.235.246</string>
    <string name="cam4_username">YWRtaW4=</string>
    <string name="cam26_tags"></string>
    <string name="cam27_password">YWRtbG9nb3M4</string>
    <int name="preference_cam31_remote_port" value="198" />
    <int name="cam34_port_rtsp" value="225" />
    <boolean name="preference_cam18_event_md_sound" value="true" />
    <int name="preference_cam13_remote_port" value="239" />
    <int name="preference_cam35_remote_port" value="220" />
    <string name="preference_cam30_name">вход в подсобку</string>
    <int name="preference_cam10_remote_port" value="195" />
    <int name="preference_cam9_port" value="208" />
    <string name="cam7_username">YWRtaW4=</string>
    <int name="cam21_protocol" value="3" />
    <int name="cam31_port_rtsp" value="198" />
    <string name="cam16_username">YWRtaW4=</string>
    <string name="preference_cam17_name">Улица вид от подиума в сторону гаражей</string>
    <string name="cam19_username">YWRtaW4=</string>
    <string name="preference_cam8_vendor">Dahua</string>
    <string name="cam35_password">TG9nb3M4ODg4OA==</string>
    <string name="preference_cam22_vendor">Dahua</string>
    <string name="preference_cam24_model">DH-SD59225U-HNI</string>
    <string name="preference_cam11_vendor">Dahua</string>
    <string name="preference_cam20_name">Улица от углового гаража</string>
    <string name="cam9_username">YWRtaW4=</string>
    <string name="preference_cam31_hostname">92.253.235.246</string>
    <int name="cam34_id" value="456725128" />
    <string name="cam22_password">YWRtbG9nb3M4</string>
    <string name="cam14_tags"></string>
    <string name="cam6_tags"></string>
    <int name="cam16_port_rtsp" value="210" />
    <string name="cam20_username">YWRtaW4=</string>
    <string name="cam26_username">YWRtaW4=</string>
    <string name="cam8_password">YWRtbG9nb3M4</string>
    <string name="preference_cam28_model">DH-SD59225U-HNI</string>
    <int name="cam5_protocol" value="3" />
    <int name="cam35_id" value="388252530" />
    <int name="cam12_id" value="1953496488" />
    <string name="preference_cam6_name">Доп.гараж в сторону фока</string>
    <string name="cam16_tags"></string>
    <int name="preference_cam23_port" value="153" />
    <string name="cam8_tags"></string>
    <string name="preference_cam29_hostname">92.253.235.246</string>
    <string name="cam14_password">YWRtbG9nb3M4</string>
    <string name="preference_cam7_vendor">Dahua</string>
    <string name="preference_cam34_vendor">Dahua</string>
    <string name="preference_cam8_name">Улица вид от дома столовая</string>
    <string name="cam32_password">TG9nb3M4ODg4OA==</string>
    <string name="preference_cam23_vendor">Dahua</string>
    <string name="preference_cam23_hostname">92.253.235.246</string>
    <string name="preference_cam19_name">Улица от столба в сторону гаражей </string>
    <int name="preference_cam21_port" value="136" />
    <string name="cam2_password">TG9nb3M4ODg4OA==</string>
    <string name="preference_cam30_model">DH-SD59225U-HNI</string>
    <string name="cam34_tags"></string>
    <string name="preference_cam25_model">DH-SD59225U-HNI</string>
    <string name="preference_cam10_hostname">92.253.235.246</string>
    <string name="preference_cam13_hostname">92.253.235.246</string>
    <int name="cam14_remote_port_rtsp" value="2554" />
    <boolean name="cam34_remote_hostname_autoupdate" value="true" />
    <string name="cam1_username">YWRtaW4=</string>
    <int name="cam27_protocol" value="3" />
    <string name="preference_cam33_model">DH-SD59225U-HNI</string>
    <string name="preference_cam12_name">Дом мамы вид от крыльца</string>
    <string name="preference_cam26_model">DH-SD59225U-HNI</string>
    <int name="cam24_protocol" value="3" />
    <int name="preference_cam1_audio_squelch" value="62" />
    <string name="preference_cam2_vendor">Dahua</string>
    <int name="cam7_remote_port_rtsp" value="24554" />
    <int name="preference_cam18_port" value="212" />
    <string name="cam10_username">YWRtaW4=</string>
    <string name="preference_cam6_remote_hostname">92.253.235.246</string>
    <int name="cam24_id" value="1247890741" />
    <string name="preference_cam26_hostname">92.253.235.246</string>
    <string name="preference_cam32_model">DH-SD59225U-HNI</string>
    <string name="preference_cam22_name">Беседка от мангала</string>
    <string name="preference_cam3_remote_hostname">92.253.235.246</string>
    <string name="preference_cam28_vendor">Dahua</string>
    <string name="preference_cam0_remote_hostname">92.253.235.246</string>
    <string name="preference_cam17_vendor">Dahua</string>
    <string name="cam17_password">YWRtbG9nb3M4</string>
    <boolean name="cam11_remote_hostname_autoupdate" value="true" />
    <int name="cam30_remote_port_rtsp" value="26554" />
    <int name="cam1_remote_port_rtsp" value="25554" />
    <int name="cam32_port_rtsp" value="207" />
    <string name="preference_cam27_model">DH-SD59225U-HNI</string>
    <int name="cam13_id" value="1857517621" />
    <int name="preference_cam28_port" value="203" />
    <int name="cam11_protocol" value="3" />
    <int name="cam4_id" value="1544874467" />
    <int name="cam0_remote_port_rtsp" value="23554" />
    <int name="cam25_id" value="778272828" />
    <string name="preference_cam1_name">Зоопарк вид на дверь</string>
    <int name="cam22_protocol" value="3" />
    <string name="cam23_tags"></string>
    <string name="cam23_username">YWRtaW4=</string>
    <int name="cam18_remote_port_rtsp" value="212" />
    <string name="preference_cam12_hostname">192.168.8.160</string>
    <string name="cam26_password">YWRtbG9nb3M4</string>
    <string name="preference_cam14_model">DH-SD59225U-HNI</string>
    <string name="cam1_tags"></string>
    <int name="cam14_protocol" value="3" />
    <string name="preference_cam17_hostname">92.253.235.246</string>
    <string name="preference_cam18_vendor">Dahua</string>
    <string name="preference_cam14_vendor">Dahua</string>
    <string name="preference_cam10_vendor">Dahua</string>
    <int name="preference_cam16_port" value="210" />
    <int name="cam13_remote_port_rtsp" value="239" />
    <boolean name="cam23_md_disarmed" value="true" />
    <int name="cam19_protocol" value="3" />
    <int name="cam0_protocol" value="3" />
    <int name="cam5_port_rtsp" value="206" />
    <string name="preference_cam7_hostname">192.168.8.69</string>
    <string name="cam31_username">YWRtaW4=</string>
    <string name="cam27_tags"></string>
    <string name="cam9_password">YWRtbG9nb3M4</string>
    <int name="cam14_id" value="330170776" />
    <string name="preference_cam5_name">Гараж вид от мастерской</string>
    <string name="cam18_password">TG9nb3M4ODg4OA==</string>
    <string name="preference_cam26_name">Лестница фок на 2 этаж</string>
    <int name="cam23_remote_port_rtsp" value="29554" />
    <string name="cam4_password">YWRtbG9nb3M4</string>
    <int name="preference_cam33_port" value="196" />
    <string name="preference_cam33_vendor">Dahua</string>
    <string name="preference_cam14_name">Улица вид вдоль бассейна от бктп</string>
    <string name="preference_cam20_hostname">192.168.8.165</string>
    <string name="preference_cam19_model">DH-SD59225U-HNI</string>
    <int name="cam20_remote_port_rtsp" value="19554" />
    <string name="preference_cam35_model">DH-SD59225U-HNI</string>
    <string name="preference_cam2_hostname">92.253.235.246</string>
    <int name="cam13_port_rtsp" value="239" />
    <string name="preference_cam25_hostname">92.253.235.246</string>
    <int name="cam8_id" value="166142303" />
    <int name="cam29_port_rtsp" value="189" />
    <string name="cam11_tags"></string>
    <int name="cam34_protocol" value="3" />
    <int name="cam10_protocol" value="3" />
    <string name="preference_cam10_name">Двор вольер Еки вид на будку</string>
    <string name="preference_cam33_hostname">92.253.235.246</string>
    <string name="cam31_tags"></string>
    <string name="preference_cam20_remote_hostname">92.253.235.246</string>
    <int name="cam35_remote_port_rtsp" value="220" />
    <boolean name="cam18_remote_hostname_autoupdate" value="true" />
    <string name="preference_cam24_hostname">92.253.235.246</string>
    <string name="cam11_username">YWRtaW4=</string>
    <int name="cam10_remote_port_rtsp" value="195" />
    <string name="cam32_tags"></string>
    <int name="cam26_protocol" value="3" />
    <string name="preference_cam22_model">DH-SD59225U-HNI</string>
    <string name="preference_cam32_vendor">Dahua</string>
    <int name="cam3_remote_port_rtsp" value="22554" />
    <string name="preference_cam3_vendor">Dahua</string>
    <string name="preference_cam21_vendor">Dahua</string>
    <string name="cam6_username">YWRtaW4=</string>
    <string name="preference_cam29_vendor">Dahua</string>
    <int name="cam26_id" value="49815" />
    <string name="preference_cam1_model">DH-SD59225U-HNI</string>
    <int name="preference_cam24_port" value="204" />
    <string name="cam30_username">YWRtaW4=</string>
    <int name="cam15_id" value="1824951761" />
    <string name="cam0_username">YWRtaW4=</string>
    <int name="cam6_id" value="1152406365" />
    <boolean name="cam23_event_md_wake_up" value="true" />
    <string name="cam19_password">YWRtbG9nb3M4</string>
    <string name="preference_cam4_name">Гараж основной вид к фоку</string>
    <string name="preference_cam35_name">Спортзал от брусьев</string>
    <string name="cam5_tags"></string>
    <string name="cam18_tags"></string>
    <string name="preference_cam35_remote_hostname">92.253.235.246</string>
    <boolean name="cam28_remote_hostname_autoupdate" value="true" />
    <int name="cam27_id" value="1854508161" />
    <string name="preference_cam14_remote_hostname">92.253.235.246</string>
    <string name="preference_cam11_remote_hostname">92.253.235.246</string>
    <int name="cam27_port_rtsp" value="238" />
    <int name="cam15_port_rtsp" value="243" />
    <string name="preference_cam16_model">DH-SD59225U-HNI</string>
    <string name="cam0_password">YWRtbG9nb3M4</string>
    <string name="preference_cam34_name">Вход в тир-студию</string>
    <string name="cam28_username">YWRtaW4=</string>
    <string name="preference_cam1_hostname">92.253.235.246</string>
    <string name="cam21_password">YWRtbG9nb3M4</string>
    <string name="cam19_tags"></string>
    <int name="cam7_id" value="1121386765" />
    <string name="cam3_password">YWRtbG9nb3M4</string>
    <int name="cam9_port_rtsp" value="208" />
    <int name="cam4_protocol" value="3" />
    <int name="cam35_protocol" value="3" />
    <int name="cam22_port_rtsp" value="63" />
    <int name="preference_cam25_port" value="217" />
    <string name="cam15_username">YWRtaW4=</string>
    <string name="preference_cam32_remote_hostname">92.253.235.246</string>
    <string name="preference_cam20_model">DH-SD59225U-HNI</string>
    <string name="cam34_password">YWRtbG9nb3M4</string>
    <int name="preference_cam29_port" value="189" />
    <string name="cam32_username">YWRtaW4=</string>
    <int name="cam13_protocol" value="3" />
    <string name="cam10_password">TG9nb3M4ODg4OA==</string>
    <int name="cam25_port_rtsp" value="217" />
    <string name="cam2_tags"></string>
    <boolean name="cam23_remote_hostname_autoupdate" value="true" />
    <string name="preference_cam15_name">Улиц вид на лестницу сбоку дома</string>
    <string name="cam14_username">YWRtaW4=</string>
    <string name="cam2_username">YWRtaW4=</string>
    <int name="preference_cam21_remote_port" value="136" />
    <string name="cam10_tags"></string>
    <boolean name="preference_cam23_event_md_sound" value="true" />
    <int name="cam16_id" value="1285859009" />
    <string name="preference_cam2_name">Попугайчик</string>
    <string name="preference_cam11_model">DH-SD59225U-HNI</string>
    <boolean name="cam1_remote_hostname_autoupdate" value="true" />
    <string name="cam20_password">YWRtbG9nb3M4</string>
    <int name="preference_cam19_remote_port" value="20554" />
    <int name="cam2_remote_port_rtsp" value="150" />
    <int name="preference_cam16_remote_port" value="210" />
    <string name="preference_cam0_name">Зоопарк вид от двери</string>
    <int name="cam1_protocol" value="3" />
    <string name="cam4_tags"></string>
    <boolean name="cam18_event_md_wake_up" value="true" />
    <int name="preference_cam27_port" value="238" />
    <int name="cam16_remote_port_rtsp" value="210" />
    <string name="preference_cam11_hostname">192.168.8.226</string>
    <string name="preference_cam13_name">Двор с дома мамы на калитку КТП</string>
    <int name="preference_cam32_port" value="207" />
    <string name="cam24_username">YWRtaW4=</string>
    <string name="preference_cam28_hostname">92.253.235.246</string>
    <string name="preference_cam8_model">DH-SD59225U-HNI</string>
    <string name="preference_cam1_remote_hostname">212.233.85.93</string>
    <string name="preference_cam7_remote_hostname">92.253.235.246</string>
    <int name="cam24_port_rtsp" value="204" />
    <int name="cam31_remote_port_rtsp" value="198" />
    <boolean name="cam23_md_oc" value="false" />
    <int name="cam23_port_rtsp" value="153" />
    <string name="cam33_password">YWRtbG9nb3M4</string>
    <string name="preference_cam9_model">DH-SD59225U-HNI</string>
    <string name="cam20_tags"></string>
    <int name="cam6_remote_port_rtsp" value="155" />
    <boolean name="cam20_remote_hostname_autoupdate" value="true" />
    <int name="cam2_port_rtsp" value="150" />
    <int name="preference_cam32_remote_port" value="207" />
    <int name="preference_cam11_remote_port" value="226" />
    <string name="preference_cam0_vendor">Dahua</string>
    <string name="preference_cam9_name">Улица от зоопарка на лавочки</string>
    <string name="preference_cam2_model">DH-SD59225U-HNI</string>
    <int name="cam15_remote_port_rtsp" value="243" />
    <string name="cam22_username">YWRtaW4=</string>
    <int name="preference_cam2_remote_port" value="150" />
    <int name="cam15_protocol" value="3" />
    <int name="cam32_remote_port_rtsp" value="207" />
    <boolean name="cam18_md_ia" value="true" />
    <int name="cam3_protocol" value="3" />
    <string name="cam30_password">YWRtbG9nb3M4</string>
    <int name="cam12_remote_port_rtsp" value="1554" />
    <string name="preference_cam11_name">Улица вид на крыльцо мамы</string>
    <boolean name="cam18_md_obj" value="true" />
    <int name="preference_cam6_remote_port" value="155" />
    <string name="preference_cam26_vendor">Dahua</string>
    <string name="preference_cam4_vendor">Dahua</string>
    <int name="cam28_id" value="109235182" />
    <string name="cam9_tags"></string>
    <int name="cam26_port_rtsp" value="197" />
    <int name="cam23_protocol" value="3" />
    <string name="preference_cam15_vendor">Dahua</string>
    <string name="preference_cam19_vendor">Dahua</string>
    <string name="cam27_username">YWRtaW4=</string>
    <string name="cam17_tags"></string>
    <int name="preference_cam17_port" value="163" />
    <int name="cam17_id" value="1026102838" />
    <string name="preference_cam12_model">DH-SD59225U-HNI</string>
    <int name="cam28_protocol" value="3" />
    <string name="preference_cam3_model">DH-SD59225U-HNI</string>
    <string name="cam0_tags"></string>
    <int name="cam0_id" value="974738174" />
    <boolean name="cam18_event_md_notification" value="true" />
    <string name="cam35_username">YWRtaW4=</string>
    <string name="preference_cam4_model">DH-SD59225U-HNI</string>
    <int name="cam29_id" value="1891041185" />
    <string name="cam17_username">YWRtaW4=</string>
    <string name="cam13_password">TG9nb3M4ODg4OA==</string>
    <string name="cam15_tags"></string>
    <string name="preference_cam23_name">Беседка на мангал</string>
    <int name="preference_cam6_port" value="155" />
    <int name="cam9_id" value="1837005020" />
    <string name="preference_cam7_model">DH-SD59225U-HNI</string>
    <string name="cam1_password">YWRtbG9nb3M4</string>
    <string name="preference_cam0_hostname">192.168.8.193</string>
    <string name="preference_cam6_hostname">92.253.235.246</string>
    <string name="preference_cam25_vendor">Dahua</string>
    <int name="preference_cam8_port" value="115" />
    <string name="preference_cam5_vendor">Dahua</string>
    <int name="cam20_protocol" value="3" />
    <string name="cam7_tags"></string>
    <string name="cam5_username">YWRtaW4=</string>
    <string name="preference_cam10_model">DH-SD59225U-HNI</string>
    <string name="preference_cam21_name">Улица вид на калитку</string>
    <int name="cam33_protocol" value="3" />
    <int name="cam9_protocol" value="3" />
    <string name="preference_cam18_name">Улица балкон бассейна </string>
    <int name="cam22_remote_port_rtsp" value="30554" />
    <string name="cam35_tags"></string>
    <int name="cam18_protocol" value="3" />
    <int name="cam6_protocol" value="3" />
    <int name="cam30_protocol" value="3" />
    <int name="cam18_id" value="1042077318" />
    <string name="preference_cam3_hostname">92.253.235.246</string>
    <string name="cam23_password">YWRtbG9nb3M4</string>
    <string name="preference_cam31_vendor">Dahua</string>
    <string name="cam25_tags"></string>
    <string name="preference_cam20_vendor">Dahua</string>
    <string name="preference_cam31_name">темная комната</string>
    <string name="preference_cam32_hostname">92.253.235.246</string>
    <int name="preference_cam22_port" value="63" />
    <string name="preference_cam28_name">Вход в фок и на эл.щитовую вход</string>
    <boolean name="cam22_remote_hostname_autoupdate" value="true" />
    <int name="cam1_port_rtsp" value="202" />
    <boolean name="preference_cam1_audio_receive_on_startup" value="true" />
    <string name="cam8_username">YWRtaW4=</string>
    <string name="preference_cam6_model">DH-SD59225U-HNI</string>
    <boolean name="preference_cam18_event_md_vibrate" value="true" />
    <int name="cam30_id" value="1862719637" />
    <string name="preference_cam7_name">Улица вид от дом на джакузи </string>
    <int name="preference_cam1_port" value="202" />
</map>
"""

# Email
cams = re.findall(r"[cam]+\d+", body)
uname = re.findall(r"username",body)
pwd = re.findall(r"password",body)

for one in cams:
    m = re.match(,body)
    print(m,one)
    if m:
        print(one, "Matched")



# print(cams,"CAMS")  # ['test@mail.com']
# print(uname,"Uname")
# print(pwd,"Passwords")
# Out:
# None cam10
# None cam16
# None cam27
# None cam30
# None cam30
# None cam18
# None cam31
# None cam31
# None cam21
# None cam13
# None cam16
# None cam35
# None cam5
# None cam34
# None cam12
# None cam32
# None cam6
# None cam3
# None cam2
# None cam2
# None cam34
# None cam16
# None cam18
# None cam19
# None cam7
# None cam13
# None cam19
# None cam22
# None cam21
# None cam3
# None cam21
# None cam1
# None cam25
# None cam6
# None cam4
# None cam24
# None cam12
# None cam26
# None cam30
# None cam33
# None cam12
# None cam18
# None cam20
# None cam29
# None cam9
# None cam15
# None cam18
# None cam17
# None cam14
# None cam33
# None cam33
# None cam8
# None cam11
# None cam3
# None cam16
# None cam29
# None cam21
# None cam18
# None cam21
# None cam28
# None cam15
# None cam19
# None cam4
# None cam1
# None cam5
# None cam7
# None cam9
# None cam30
# None cam27
# None cam34
# None cam5
# None cam31
# None cam29
# None cam25
# None cam32
# None cam10
# None cam24
# None cam12
# ...

# %%
import re

text = "My email is test@mail.com and phone is +123-456-789."

# Email
emails = re.findall(r"[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}", text)
print(emails)  # ['test@mail.com']

# Телефон
phones = re.findall(r"\+\d{3}-\d{3}-\d{3}", text)
print(phones)  # ['+123-456-789']

# Найти слово "email" в начале строки (игнор регистра)
if re.match(r"(?i)^my", text):
    print("Начинается с 'my'")
# Out:
# ['test@mail.com']
# ['+123-456-789']
# Начинается с 'my'

# %%
import re


somestr = """{'id_port': 8, 'c_x': 937, 'c_y': 331, 'height': 217, 'width': 949}
{'id_port': 12, 'c_x': 875, 'c_y': 395, 'height': 155, 'width': 885}
{'id_port': 16, 'c_x': 860, 'c_y': 446, 'height': 140, 'width': 834}
{'id_port': 20, 'c_x': 884, 'c_y': 531, 'height': 164, 'width': 749}
{'id_port': 0, 'c_x': 1156, 'c_y': 598, 'height': 436, 'width': 682}
{'id_port': 4, 'c_x': 1001, 'c_y': 463, 'height': 281, 'width': 817}
{'id_port': 8, 'c_x': 1048, 'c_y': 469, 'height': 328, 'width': 811}
{'id_port': 12, 'c_x': 1043, 'c_y': 515, 'height': 323, 'width': 765}
{'id_port': 16, 'c_x': 1046, 'c_y': 550, 'height': 326, 'width': 730}
{'id_port': 20, 'c_x': 1037, 'c_y': 580, 'height': 317, 'width': 700}"""


res_one = re.findall('\d',somestr)
res_two =re.findall('\d[0-9]',somestr)
res_three = re.findall('\d[0-9][0-9]',somestr)

# full_list = [res_one,res_two,res_three]
# full_list

res_one
# Out:
# ['8',
#  '9',
#  '3',
#  '7',
#  '3',
#  '3',
#  '1',
#  '2',
#  '1',
#  '7',
#  '9',
#  '4',
#  '9',
#  '1',
#  '2',
#  '8',
#  '7',
#  '5',
#  '3',
#  '9',
#  '5',
#  '1',
#  '5',
#  '5',
#  '8',
#  '8',
#  '5',
#  '1',
#  '6',
#  '8',
#  '6',
#  '0',
#  '4',
#  '4',
#  '6',
#  '1',
#  '4',
#  '0',
#  '8',
#  '3',
#  '4',
#  '2',
#  '0',
#  '8',
#  '8',
#  '4',
#  '5',
#  '3',
#  '1',
#  '1',
#  '6',
#  '4',
#  '7',
#  '4',
#  '9',
#  '0',
#  '1',
#  '1',
#  '5',
#  '6',
#  '5',
#  '9',
#  '8',
#  '4',
#  '3',
#  '6',
#  '6',
#  '8',
#  '2',
#  '4',
#  '1',
#  '0',
#  '0',
#  '1',
#  '4',
#  '6',
#  '3',
#  '2',
#  '8',
#  '1',
#  '8',
#  '1',
#  '7',
#  '8',
#  '1',
#  '0',
#  '4',
#  '8',
#  '4',
#  '6',
#  '9',
#  '3',
#  '2',
#  '8',
#  '8',
#  '1',
#  '1',
#  '1',
#  '2',
#  '1',
#  '0',
#  '4',
#  '3',
#  '5',
#  '1',
#  '5',
#  '3',
#  '2',
#  '3',
#  '7',
#  '6',
#  '5',
#  '1',
#  '6',
#  '1',
#  '0',
#  '4',
#  '6',
#  '5',
#  '5',
#  '0',
#  '3',
#  '2',
#  '6',
#  '7',
# ...

# %%
import re

txt = "The rain in Spain"
x = re.search("\s", txt)

print("The first white-space character is located in position:", x.start())
# Out:
# The first white-space character is located in position: 3

# %%
import re

text = "The best way to learn regex is trying it in the jupyter"
pattern = "regex"

patNum = 
res = re.findall(pattern,text)

res
# Out:
# ['regex']

# %%
# returns match object

import re

txt = "The rain in Spain and in Portugal"
x = re.search("Portugal", txt)
print(type(x))
x
# Out:
# <class 're.Match'>
# <re.Match object; span=(25, 33), match='Portugal'>

# %%
import re

# sub - because it is substitute

body = "Mom says that you should do these trainings each month"
original = "month"
new = "day"

res = re.sub(original,new,body) 

res
# Out:
# 'Mom says that you should do these trainings each day'

# %%
# re.split(A, B) split string B into a list using the delimiter A
import re 

body = "There is so long text that should be split in parts with delimiter"

delimiter = '\s' # tab

res = re.split(delimiter,body)


type(res)
# Out:
# list

# %%
import re

pat = r'max'

body = 'this tring has maxim maximillian maxymax maxmaxmax times of maximum'

re.findall(pat,body)
# Out:
# ['max', 'max', 'max', 'max', 'max', 'max', 'max', 'max']

# %%
import re

phone_pattern = r"^\+?\d{1,3}?[-.\s]?\(?\d{3}\)?[-.\s]?\d{3}[-.\s]?\d{4}$"

# Assumes at least a first and last name with a space in between
name_pattern = r"^[a-zA-Z]"


body = "This text has few names also has phone numbers that are users with names Anna Kovaleva, Kostya Makoedov, Vanya Goncharov, so they has fone numbers like +79855203082, +7 365-667-22-55, 89885441382"

res = re.match(name_pattern,body)

print(res.string)
# Out:
# This text has few names also has phone numbers that are users with names Anna Kovaleva, Kostya Makoedov, Vanya Goncharov, so they has fone numbers like +79855203082, +7 365-667-22-55, 89885441382

# %%
# {n,m}	от n до m повторов	\d{2,4} → 12, 1234

text = 'The te33st te11xt55 is +987656789dsfsghgf 1 22 33 4444 then Iv4an88 +TTT--xx 00909'


for i in range(1,9):
    res = re.findall(f'[1-{i}]\w[a-z].',text)
    print(res)
# Out:
# ['11xt']
# ['11xt']
# ['33st', '11xt']
# ['33st', '11xt', '4an8']
# ['33st', '11xt', '4an8']
# ['33st', '11xt', '4an8']
# ['33st', '11xt', '4an8']
# ['33st', '11xt', '89ds', '4an8']
