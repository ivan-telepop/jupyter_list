# %%
# Это почитать !!!
# https://docs-python.ru/standart-library/modul-re-python/

# %%
# Кароч есть сторака типа: 'qwertyuiop'
# Нужно вывести по парам из длинной строки 'qwertyuiop'
# Если пара не получается, заменить символом _ Чтоб смотрелось так- 'qw' 'er' 'ty' 'ui' 'o_'

# Complete the solution so that it splits the string into pairs of two characters. If the string contains an odd number of characters then it should replace the missing second character of the final pair with an underscore ('_').


# https://www.codewars.com/kata/515de9ae9dcfc28eb6000001/python







s = 'qwertyuiopxsdfghjkxasdfghjklzxcvbnm'





for i in range(0,len(s),2):
    if (i+1) < len(s):
        print(s[i] + s[i+1])
    else:
        print(s[i] + '_')
# Out:
# qw
# er
# ty
# ui
# op
# xs
# df
# gh
# jk
# xa
# sd
# fg
# hj
# kl
# zx
# cv
# bn
# m_

# %%
import re


# pattern = '.' соответствует любому символу, кроме новой строки - {2} символа из s и + "_" ...
def foo(s):
    return re.findall(".{2}", s + "_")


foo('sdfghjkytrefgh')
# Out:
# ['sd', 'fg', 'hj', 'ky', 'tr', 'ef', 'gh']

# %%
# Give your answer as a string matching "odd" or "even".

# If the input array is empty consider it as: [0] (array with a zero).

# Examples:
# Input: [0]
# Output: "even"

# Input: [0, 1, 4]
# Output: "odd"

# Input: [0, -1, -5]
# Output: "even"

a = list((-2,0,4,-3,8,9,3,2,-6))

# b = map(lambda x: abs(x),arr)

def odd_or_even(arr: list) -> str:
    return 'even' if sum(map(lambda x: abs(x),arr)) %  2 == 0 else 'odd'

odd_or_even(a)
# Out:
# 'odd'

# %%
# Jack really likes his number five: the trick here is that you have to multiply each number by 5 
# raised to the number of digits of each numbers, so, for example:

#   3 -->    15  (  3 * 5¹)
#  10 -->   250  ( 10 * 5²)
# 200 --> 25000  (200 * 5³)
#   0 -->     0  (  0 * 5¹)
#  -3 -->   -15  ( -3 * 5¹)


def multiply(num: int):
    return num * pow(5,len(str(abs(num))))




multiply(200)
# Out:
# 25000

# %%
# У вас есть список дневных заработков на фрилансе. Вы можете работать или пропускать эти дни. Вы можете работать до k дней подряд, 
# но после этого вы должны взять как минимум один день отдыха, в течение которого вы ничего не зарабатываете.

# Ваша задача — определить максимальный общий заработок, который вы можете получить, следуя этому правилу.

# Входные данные:
# заработок: массив неотрицательных целых чисел (0 <= длина заработка < 100).

# k: целое число, представляющее максимальное количество последовательных рабочих дней (1 <= k < 100).
# Выходные данные:
# целое число, представляющее максимальный заработок, который вы можете получить, соблюдая правило обязательного перерыва.
# Пример
# Для дохода = [60, 70, 80, 40, 80, 90, 100, 20], k = 3, вернуть 480. Отказаться от дохода 40 и 20.

# Для дохода = [45, 12, 78, 34, 56, 89, 23, 67, 91], k = 4, вернуть 460. Отказаться от дохода 12 и 23.

arr = [60, 70, 80, 40, 80, 90, 100, 20]

# def count_earnings(arr,k):
#     res = []
#     tk = k
#     for i in range(1,len(arr)):
#         print("Counter is:", i)
#         if i == tk and len(arr) > tk:
#             res.append(arr[tk])
#             tk +=k +1
#     return sum(arr) - sum(res) 
    
        
# count_earnings([60, 70, 80, 40, 80, 90, 100, 20],3)

arr2 = [45, 12, 78, 34, 56, 89, 23, 67, 91]

# def maximize_earnings(earnings,k):
#     indA = [ i for i in range(0,len(arr),k)]
#     for i in range(

indexes = each k

slices 

find lowes in each slice




maximize_earnings(arr2,4)
# Out:
# EARNINGS 89
# [89]
# 406
