# %%
# day items dictionary
day_items = dict(
    left_col=490.41,   # левая колонка литры
    right_col=235.03, # правая колонка литры
    low_price_liters=288.23, # литры по сниженной цене
    cashless_amount=5552 # сумма по безналичному расчету
)


def calculate_day(day_items):
    """Method takes as an argument:
    agrs: day_items: dict
    returns: float (calculated amount of money)
    """
    both_cols_amount = (day_items['left_col'] + day_items['right_col']) * 28 # All roubles
    minus_low = (day_items['low_price_liters'] * 2) # Roubles that sould be substracted from whole amount
    return both_cols_amount - day_items['cashless_amount']  - minus_low
        


calculate_day(day_items)   #490.41,235.03,288.23,5552)
# Out:
# 14183.86

# %%
print({'a','b','c'}.isdisjoint({'d','e','f'})) # True
print("\n")
# Out:
# True

# %%
class DataItems:
    def __init__(self,left_col,right_col,low_price_liters,cashless_amount):
        self.left_col: float = left_col
        self.right_col:float = right_col
        self.low_price_liters:float = low_price_liters
        self.cashless_amount:float = cashless_amount
        

class DayReport:
    __slots__ = ('left_col','right_col','low_price_liters','cashless_amount')
    def __init__(self,data_it):
        self.__dict__ = dict()
        for name in self.__slots__:
            self.__dict__[name] = data_it.__dict__[name]
        


day = DataItems(490.41,235.03,288.23,5552)

rep = DayReport(day)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[90], line 20
#      14             self.__dict__[name] = data_it.__dict__[name]
#      18 day = DataItems(490.41,235.03,288.23,5552)
# ---> 20 rep = DayReport(day)
#
# Cell In[90], line 12, in DayReport.__init__(self, data_it)
#      11 def __init__(self,data_it):
# ---> 12     self.__dict__ = {}
#      13     for name in self.__slots__:
#      14         self.__dict__[name] = data_it.__dict__[name]
#
# AttributeError: 'DayReport' object has no attribute '__dict__'
