# %%
# proper article pyproject.toml : https://realpython.com/python-pyproject-toml/

# %%
# virtualenv -p Python3.10 .venv

# source .venv/bin/activate

# pip install .

# %%
# setuptools — это стандартный инструмент упаковки и сборки Python-проектов, позволяющий:

# 📦 собрать проект в wheel или tar.gz

# 🧩 управлять зависимостями (install_requires)

# 🛠 установить проект локально (pip install .)

# 🧪 добавить консольные команды (entry_points)

# 📁 указать, какие файлы включать в дистрибутив

# Это современная замена старому distutils.

# 🔧 Где он используется?
# Сейчас он обычно вызывается через pyproject.toml:


# [build-system]
# requires = ["setuptools>=61.0"]
# build-backend = "setuptools.build_meta"
# А основная настройка проекта указывается либо:

# в pyproject.toml (рекомендуется)

# или в старом setup.py (устарело, но всё ещё поддерживается)

# ✅ Минимальная конфигурация с setuptools через pyproject.toml

# [build-system]
# requires = ["setuptools>=61.0"]
# build-backend = "setuptools.build_meta"

# [project]
# name = "my_project"
# version = "0.1.0"
# description = "Пример проекта на setuptools"
# requires-python = ">=3.9"
# dependencies = [
#   "fastapi",
#   "sqlalchemy"
# ]

# [tool.setuptools]
# package-dir = {"" = "src"}

# [tool.setuptools.packages.find]
# where = ["src"]
# Структура проекта:
# css

# my_project/
# ├── pyproject.toml
# ├── src/
# │   └── my_project/
# │       └── __init__.py
# └── ...
# 🚀 Основные команды
# bash

# # Установить проект в режиме разработки (editable)
# pip install -e .

# # Собрать wheel
# python -m build --wheel
# Для build нужен пакет:

# bash
# Copy
# Edit
# pip install build
# 🔌 Расширенные возможности setuptools
# entry_points — создание CLI:

# toml

# [project.scripts]
# mycli = "my_project.cli:main"
# include / exclude — управлять включаемыми файлами

# package_data — включить не-Python файлы в дистрибутив

# 🧠 Когда использовать setuptools?
# Ты почти всегда используешь setuptools, даже если напрямую этого не видишь — pip install . под капотом вызывает его.
# Если ты не используешь Poetry или Hatch — это твой основной инструмент упаковки.
