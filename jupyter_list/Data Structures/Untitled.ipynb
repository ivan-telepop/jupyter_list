# %%
class Book:
   def __init__(self, title):
       self.title = title

   def __str__(self):
       return self.title



boo = Book('Title of the Book')

boo.__str__()
# Out:
# 'Title of the Book'
