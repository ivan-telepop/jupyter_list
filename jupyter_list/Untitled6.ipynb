# %%
import random
ls1 = [1,4,8,9,77]


def calc(a,b):
    return a * b
    

ls2 = [ calc(i, ) for i in range(1,10) ]

ls1[0],ls1[1],ls1[2],ls1[3],ls1[4] = ls1[4],ls1[3],ls1[2],ls1[1],ls1[0]

ls1
# Out:
#   Cell In[8], line 9
#     ls2 = [ calc( i, random.randint(2,44) for i in range(1,10) ]
#                                                                ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('
