// %% [markdown]
// 1. Adding/Removing Elements:
// push(...items): Adds one or more elements to the end of an array.
// pop(): Removes the last element from an array and returns it.
// unshift(...items): Adds one or more elements to the beginning of an array.
// shift(): Removes the first element from an array and returns it.
// splice(startIndex, deleteCount, ...items): A versatile method for adding, removing, or replacing elements at any position within an array.

// %%
// splice example
let myArr = ['one','two','three','four','five','six'];

let items = [2,3,4];

let nArr = myArr.splice(1,3,...items);

console.log("These are deleted: ", nArr)

console.log("myArr are changed with method splice:", myArr)
// Out:
// These are deleted:  [ "two", "three", "four" ]
// myArr are changed with method splice: [ "one", 2, 3, 4, "five", "six" ]

// %%
2. Accessing and Searching Elements:
at(index): Returns the element at a specified index, supporting negative indices to count from the end.
indexOf(element, fromIndex): Returns the first index at which a given element can be found, or -1 if not present.
lastIndexOf(element, fromIndex): Returns the last index at which a given element can be found, or -1 if not present.
includes(element, fromIndex): Checks if an array contains a specified element, returning true or false.
find(callbackFunction): Returns the value of the first element in the array that satisfies the provided testing function.
findIndex(callbackFunction): Returns the index of the first element in the array that satisfies the provided testing function.

// %%
3. Iteration and Transformation:

forEach(callbackFunction): Executes a provided function once for each array element.
    
map(callbackFunction): Creates a new array populated with the results of calling a provided function on every element in the calling array.
    
filter(callbackFunction): Creates a new array with all elements that pass the test implemented by the provided function.
    
reduce(callbackFunction, initialValue): Executes a reducer function on each element of the array, resulting in a single output value.
    
some(callbackFunction): Checks if at least one element in the array satisfies the provided testing function. 
    
every(callbackFunction): Checks if all elements in the array satisfy the provided testing function.

// %%
let myArr = ['one','two','three','four','five','six'];

let doDo = function(item){
    return "Here is number: ${item} << things."
}

let

// %%
4. Utility Methods:
length: A property that returns the number of elements in an array.
toString(): Returns a string representing the specified array and its elements.
join(separator): Joins all elements of an array into a string, separated by a specified separator.
concat(...arrays): Returns a new array containing the elements of the original array joined with other arrays or values.
slice(startIndex, endIndex): Returns a shallow copy of a portion of an array into a new array object.
sort(compareFunction): Sorts the elements of an array in place and returns the sorted array.
reverse(): Reverses the order of the elements in an array in place.
flat(depth): Creates a new array with all sub-array elements concatenated into it recursively up to the specified depth.
flatMap(callbackFunction): Maps each element using a mapping function, then flattens the result into a new array.
