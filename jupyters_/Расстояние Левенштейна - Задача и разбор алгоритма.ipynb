# %%
# Грубое - простое решение нахождения Расстояние Дамерау — Левенштейна

from collections import Counter
import difflib


# Есть две строки 
str_a = 'rosenblat'

str_b = 'rosenbloom'

# str_a = 'telepop'
# str_b = 'popelet'


# Объект диффер 

dif_obj = difflib.Differ()


# Разница в строках - ['  r', '  o', '  s', '  e', '  n', '  b', '  l', '- a', '- t', '+ o', '+ o', '+ m']
difference = dif_obj.compare(str_a,str_b)

# print("Разница в объекте difference:",[*difference])

mrk = ['+','-']

res = []

for y in difference:
    foo = y.split()
    if len(foo) >= 2 and foo[0] in mrk:
        res.append(foo)

        
print('Расстояние Левенштейна равно:',len(res))
# Out:
# Расстояние Левенштейна равно: 5

# %%
from difflib import Differ, SequenceMatcher
str_a = 'telepop'
str_b = 'popelet'

df = Differ()

di = df.compare(str_a,str_b)


sm = SequenceMatcher(None,str_a,str_b).ratio()

sm
# Out:
# 0.42857142857142855

# %%
import difflib 
  
# assign parameters 
par1 = 'GFG'
par2 = 'gfg'
  
# compare 
matches = difflib.SequenceMatcher( 
    None, par1, par2).get_matching_blocks() 
  
for ele in matches: 
    print(par1[ele.a:ele.a + ele.size])
