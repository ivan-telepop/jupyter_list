# %%
import yaml


config_data = {
    'device params': {
        'device name': 'Operand X 1',
        'owner': 'Alyosha Popovich',
        'network': {
            'ip_adress': '192.168.0.66',
            'mask': '255.255.255.0',
            'dns': ['192.168.0.1', '8.8.8.8', '9.9.9.9'],
            'host_name': 'My Lovely device',
            'remote_server': '29.82.11.77',
            'remote_api_key': 'token-bla-bla-bla',
        'meter-one': {
            'type': 'hot_water',
            'initial_values': '0.567',
            'tariffs': ['day', 'night', 'peak'],
        }
            
        }
    }
}

# Writing nested data to a YAML file
with open('config_data.yaml', 'w') as file:
    yaml.dump(config_data, file)

print("Nested data has been written to 'nested_data.yaml'")
# Out:
# Nested data has been written to 'nested_data.yaml'

# %%
# READ DATA

with open('config_data.yaml', 'r') as file:
    loaded_data = yaml.safe_load(file)

# print("Data read from 'config_data.yaml':")
print(loaded_data['device params']['network'])
# Out:
# {'dns': ['192.168.0.1', '8.8.8.8', '9.9.9.9'], 'host_name': 'My Lovely device', 'ip_adress': '192.168.0.66', 'mask': '255.255.255.0', 'meter-one': {'initial_values': '0.567', 'tariffs': ['day', 'night', 'peak'], 'type': 'hot_water'}, 'remote_api_key': 'token-bla-bla-bla', 'remote_server': '29.82.11.77'}
