# %%
ls = [ i for i in 'hellohunny' ]

ff = iter(ls)


next(ff,'o')
# Out:
# 'h'

# %%
# I T E R
# with no sentinel it works like simple iterator __next__ under the hood


mng = iter(range(1,10))

print(next(mng))
print(next(mng))
print(next(mng))
print(next(mng))
# Out:
# 1
# 2
# 3
# 4

# %%
ls = [ i for i in range(1,10)]





qq = iter(ls)



print(next(qq))
print(next(qq))
print(next(qq))
print(next(qq)) 
print(next(qq))
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Out:
# []

# %%
ll = []

bool(ll)
# Out:
# False
