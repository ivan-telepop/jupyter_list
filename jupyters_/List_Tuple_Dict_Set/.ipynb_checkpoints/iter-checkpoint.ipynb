# %%
# I T E R
# with no sentinel it works like simple iterator __next__ under the hood


mng = iter(range(1,10))

print(next(mng))
print(next(mng))
print(next(mng))
print(next(mng))
# Out:
# 1
# 2
# 3
# 4

# %%
import datetime
currtime = datetime.datetime.now()

with open('iter.txt','w') as file:
    for line in range(10):
        file.write(f" {str(id(currtime))}  {currtime} \n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       4 with open('iter.txt','w') as file:
#       5     for line in range(10):
# ----> 6         file.write(f" {str(id(currtime))}  {currtime} \n")
#
# NameError: name 'currtime' is not defined
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# -------
#
# ...
