// %%
// Type

// Тип мы обьявляем так
type Point = {
    x: string,
    y: number,
}
// or such
type stringOrNumber = string | number;


// EXENDING  such
type NewPoint = Point & {
    newValue: number;
}


let foo: Point = {x:'some x', y: 155}


foo
// Out:
// { x: "some x", y: 155 }

// %%
// Интерфейс по другому ( без = ) Интерфейс можно экстендить - extend!

interface InterPoint {
    x: string,
    y: number,
};

// Extension of interPoint  - Так мы экстендим интерфейс через директиву - extends
interface EXTpoint extends InterPoint {
    name: stringOrNumber,
}


// REDEFINING look on it !!!

interface One {
    a: number,
}
//  мы повторно переопределив довали новый параметр в интерфейс
interface One {
    b: string,
}

/// ----------------------



function print(a: stringOrNumber) {
    console.log( a );
}
function make(snum: stringOrNumber, point: Point) {
    return snum * point;
}

// make(4,8)

// C A S T 

const cf = (one: One) => {
    const bb: InterPoint = one as EXTpoint;
    console.log(bb);
}


cf(33)
// Out:
// 33

// %%
const docxx = document.getElementById('head') as EXTpoint;  // Так выглядит каст к типу но он тут не пашет !!!
// Out:
// Stack trace:
// ReferenceError: document is not defined
//     at <anonymous>:1:36
