// %%
Короткий набор базовых паттернов JavaScript — без лишнего.

1. Переменные
const a = 1        // неизменяемая ссылка
let b = 2          // можно менять
var c = 3          // старый способ (почти не используют)
2. Условия
if (x > 0) {
  ...
} else if (x === 0) {
  ...
} else {
  ...
}
const result = x > 0 ? 'ok' : 'fail'
switch (type) {
  case 'a': break
  default: break
}
3. Циклы
for (let i = 0; i < 10; i++) {}
for (const item of arr) {}
for (const key in obj) {}
while (cond) {}
4. Функции
function foo(a, b) {
  return a + b
}
const foo = (a, b) => a + b
const foo = ({ a, b }) => a + b   // деструктуризация
5. Объекты
const user = {
  name: 'Ivan',
  age: 25,
  greet() {
    return 'hi'
  }
}

Доступ:

user.name
user['name']
6. Массивы
const arr = [1, 2, 3]

arr.map(x => x * 2)
arr.filter(x => x > 1)
arr.find(x => x === 2)
7. Деструктуризация
const { name, age } = user
const [a, b] = arr
8. Spread / Rest
const newArr = [...arr]

const newObj = { ...user, age: 30 }

function foo(...args) {}
9. Классы
class User {
  constructor(name) {
    this.name = name
  }

  greet() {
    return this.name
  }
}

Наследование:

class Admin extends User {}
10. Асинхронность
async function foo() {
  const data = await fetch(url)
}
fetch(url).then(res => res.json())
11. Проверки / валидация
if (!value) {}              // falsy check

if (typeof x === 'string') {}

if (Array.isArray(arr)) {}
if ('name' in user) {}
const isValid = !!user.name && user.age > 18
12. Optional chaining
user?.address?.city
13. Nullish coalescing
const name = user.name ?? 'default'
14. Pattern matching (частично)

В JS нет нормального pattern matching (как в Python/Scala), но есть замены:

switch + условия

switch (true) {
  case x > 10: break
}

деструктуризация

const { type } = obj
15. Генераторы
function* gen() {
  yield 1
  yield 2
}
const g = gen()
g.next()
16. Работа с ошибками
try {
  ...
} catch (e) {
  ...
} finally {
  ...
}
17. Модули
export const a = 1
export default foo
import foo, { a } from './file.js'
18. Частые паттерны

Guard

if (!user) return

Immutable update

const updated = { ...user, age: 30 }

Chain

arr.filter(...).map(...).reduce(...)

// %%
let userName = prompt("Please enter your name:", "Guest");

if (userName === null || userName === "") {
    alert("You did not enter a name or canceled the input.");
} else {
    alert(`Hello, ${userName}!`);
}
// Out:
// Please enter your name: [Guest] null
