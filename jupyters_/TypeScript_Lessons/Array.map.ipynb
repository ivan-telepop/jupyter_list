// %%
const arrOne = [1,2,3,4,5];

const mappedArr = arrOne.map((elem) => {
    let foo = `Elem is: ${elem}`;
    console.log(foo)
})
// Out:
// Elem is: 1
// Elem is: 2
// Elem is: 3
// Elem is: 4
// Elem is: 5

// %%
const response = await fetch('http://localhost:8000/users');
const users = await response.json()

// const usersMapped = users.map((user, id) => {
//     let bar = `ID: ${id} Login: ${user.login}`;
//     console.log(bar)
// })

// Функция, которую мы передаём в метод map(), может принимать три параметра:

// item — элемент массива в текущей итерации;
// index — индекс текущего элемента;
// arr — сам массив, который мы перебираем.







const mappedUsers = users.map((user, id) => {
    return {"id": id,"name": user.login, "token": user.token}
})

mappedUsers
// Out:
// [
//   {
//     id: 0,
//     name: "Lysanne25@yahoo.com",
//     token: "Bearer:86909068473472988078oahRFNNI_WPVrKv"
//   },
//   {
//     id: 1,
//     name: "Marcel_Russel21@hotmail.com",
//     token: "Bearer:51297336355728698346fixyA5TOP9LsH4s"
//   },
//   {
//     id: 2,
//     name: "Bennie72@yahoo.com",
//     token: "Bearer:127630231151996026120ekQ9aEFf7b6R9c"
//   },
//   {
//     id: 3,
//     name: "Toni10@yahoo.com",
//     token: "Bearer:92911519589635372776M0kREs8plLk56ps"
//   },
//   {
//     id: 4,
//     name: "Lonie25@hotmail.com",
//     token: "Bearer:51824291786363392831DH_cwLVg2DnOEZ6"
//   },
//   {
//     id: 5,
//     name: "Pinkie.Doyle@hotmail.com",
//     token: "Bearer:34542552870838523303CWURHP6uDOZ6xMV"
//   },
//   {
//     id: 6,
//     name: "Celestine89@yahoo.com",
//     token: "Bearer:60350465495341884960I8nPYOBb2Mv815W"
//   },
//   {
//     id: 7,
//     name: "Georgianna_Buckridge@gmail.com",
// ...
