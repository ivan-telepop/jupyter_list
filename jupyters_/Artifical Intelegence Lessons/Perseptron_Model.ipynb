# %%
# !python -m venv .venv
# !source .venv/bin/activate 
# !pip install numpy

# %%
# Simple Model of Perseptron

# Допустим у нас есть персептрон с сенсорами - массив значений в качестве аргумента
# мы знаем что значение S элемента формируется сквозь вес А 
# Говорит сенсору - Ты либо 1 либо 0 - Связь сенсора с А элементом равна по любасу 1 ! 
# (Умножаем на 1, что бы не прилетело с сенсора)
# С сенсора пришло 0 ? - Умножается на 1
# С сенсора пришло 1 ? - Умножается на 1
# - Я не понимаю почему нельзя просто суммировать все S... Но по факту мы получаем на выходе А элемента либо 1 / 0



def perceptron(Sensor):
    treshold = 7 # Пороговое значение
    init_val = 0 # Стартовое значение
    for i in range(15):
        init_val += int(Sensor[i]) * weights[i] # Проходим по всем сенсорам и умножаем на веса (1)
    if init_val >= treshold:
        return True
    else:
        return False

num1 = list('101010100101000')
num2 = list('001010001010111')

weights = [ 1 for i in range(15)]


print(perceptron(num1),sum([int(i) for i in num1]))

print(perceptron(num2),sum([int(i) for i in num2]))
# Out:
# False 6
# True 7

# %%
import sys
print(sys.executable)
# Out:
# /usr/local/Cellar/jupyterlab/4.5.4/libexec/bin/python

# %%
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#
# ModuleNotFoundError: No module named 'numpy'
