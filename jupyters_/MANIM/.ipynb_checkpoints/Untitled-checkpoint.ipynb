# %%
# !pip install IPython==8.21.0
# Out:
# Requirement already satisfied: IPython==8.21.0 in /Users/ewan/Desktop/Dev/jupyter_list/.venv/lib/python3.14/site-packages (8.21.0)
# Requirement already satisfied: decorator in /Users/ewan/Desktop/Dev/jupyter_list/.venv/lib/python3.14/site-packages (from IPython==8.21.0) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /Users/ewan/Desktop/Dev/jupyter_list/.venv/lib/python3.14/site-packages (from IPython==8.21.0) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/ewan/Desktop/Dev/jupyter_list/.venv/lib/python3.14/site-packages (from IPython==8.21.0) (0.2.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/ewan/Desktop/Dev/jupyter_list/.venv/lib/python3.14/site-packages (from IPython==8.21.0) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/ewan/Desktop/Dev/jupyter_list/.venv/lib/python3.14/site-packages (from IPython==8.21.0) (2.19.2)
# Requirement already satisfied: stack-data in /Users/ewan/Desktop/Dev/jupyter_list/.venv/lib/python3.14/site-packages (from IPython==8.21.0) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /Users/ewan/Desktop/Dev/jupyter_list/.venv/lib/python3.14/site-packages (from IPython==8.21.0) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /Users/ewan/Desktop/Dev/jupyter_list/.venv/lib/python3.14/site-packages (from IPython==8.21.0) (4.9.0)
# Requirement already satisfied: wcwidth in /Users/ewan/Desktop/Dev/jupyter_list/.venv/lib/python3.14/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython==8.21.0) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/ewan/Desktop/Dev/jupyter_list/.venv/lib/python3.14/site-packages (from jedi>=0.16->IPython==8.21.0) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/ewan/Desktop/Dev/jupyter_list/.venv/lib/python3.14/site-packages (from pexpect>4.3->IPython==8.21.0) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/ewan/Desktop/Dev/jupyter_list/.venv/lib/python3.14/site-packages (from stack-data->IPython==8.21.0) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/ewan/Desktop/Dev/jupyter_list/.venv/lib/python3.14/site-packages (from stack-data->IPython==8.21.0) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/ewan/Desktop/Dev/jupyter_list/.venv/lib/python3.14/site-packages (from stack-data->IPython==8.21.0) (0.2.3)
#
# [notice] A new release of pip is available: 26.0 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install manim
# Out:
# Collecting manim
#   Downloading manim-0.20.1-py3-none-any.whl.metadata (10 kB)
# Collecting audioop-lts>=0.2.1 (from manim)
#   Downloading audioop_lts-0.2.2-cp313-abi3-macosx_10_13_x86_64.whl.metadata (2.0 kB)
# Collecting av>=15.0 (from manim)
#   Downloading av-17.1.0-cp311-abi3-macosx_11_0_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: beautifulsoup4>=4.12 in /Users/ewan/Desktop/Dev/jupyter_list/.venv/lib/python3.14/site-packages (from manim) (4.14.3)
# Collecting click>=8.0 (from manim)
#   Using cached click-8.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting cloup>=2.0.0 (from manim)
#   Downloading cloup-3.1.0-py2.py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: decorator>=4.3.2 in /Users/ewan/Desktop/Dev/jupyter_list/.venv/lib/python3.14/site-packages (from manim) (5.2.1)
# Collecting isosurfaces>=0.1.1 (from manim)
#   Downloading isosurfaces-0.1.2-py3-none-any.whl.metadata (3.3 kB)
# Collecting manimpango<1.0.0,>=0.6.1 (from manim)
#   Downloading manimpango-0.6.1-cp314-cp314-macosx_10_15_x86_64.whl.metadata (8.2 kB)
# Collecting mapbox-earcut>=1.0.0 (from manim)
#   Downloading mapbox_earcut-2.0.0-cp314-cp314-macosx_10_15_x86_64.whl.metadata (2.5 kB)
# Collecting moderngl-window>=2.0.0 (from manim)
#   Downloading moderngl_window-3.1.1-py3-none-any.whl.metadata (9.0 kB)
# Collecting moderngl<6.0.0,>=5.7.0 (from manim)
#   Downloading moderngl-5.12.0.tar.gz (193 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting networkx>=2.6 (from manim)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: numpy>=2.1 in /Users/ewan/Desktop/Dev/jupyter_list/.venv/lib/python3.14/site-packages (from manim) (2.4.2)
# Collecting pillow>=11.0 (from manim)
#   Downloading pillow-12.2.0-cp314-cp314-macosx_10_15_x86_64.whl.metadata (8.8 kB)
# Collecting pycairo<2.0.0,>=1.14 (from manim)
#   Downloading pycairo-1.29.0.tar.gz (665 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 665.9/665.9 kB 7.3 MB/s  0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pydub>=0.22.0 (from manim)
#   Using cached pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: pygments>=2.17 in /Users/ewan/Desktop/Dev/jupyter_list/.venv/lib/python3.14/site-packages (from manim) (2.19.2)
# Collecting rich>=12.0.0 (from manim)
#   Using cached rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting scipy>=1.13.0 (from manim)
#   Downloading scipy-1.17.1-cp314-cp314-macosx_14_0_x86_64.whl.metadata (62 kB)
# Collecting screeninfo>=0.7.0 (from manim)
#   Downloading screeninfo-0.8.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting skia-pathops>=0.9.0 (from manim)
#   Downloading skia_pathops-0.9.2-cp310-abi3-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting srt>=3.0.0 (from manim)
#   Downloading srt-3.5.3.tar.gz (28 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting svgelements>=1.9.0 (from manim)
#   Downloading svgelements-1.9.6-py2.py3-none-any.whl.metadata (44 kB)
# Collecting tqdm>=4.21.0 (from manim)
#   Downloading tqdm-4.68.2-py3-none-any.whl.metadata (58 kB)
# Requirement already satisfied: typing-extensions>=4.12.0 in /Users/ewan/Desktop/Dev/jupyter_list/.venv/lib/python3.14/site-packages (from manim) (4.15.0)
# Collecting watchdog>=2.0.0 (from manim)
#   Downloading watchdog-6.0.0.tar.gz (131 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting glcontext>=3.0.0 (from moderngl<6.0.0,>=5.7.0->manim)
#   Downloading glcontext-3.0.0.tar.gz (16 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/ewan/Desktop/Dev/jupyter_list/.venv/lib/python3.14/site-packages (from beautifulsoup4>=4.12->manim) (2.8.3)
# Collecting pyglet>=2.0.0 (from moderngl-window>=2.0.0->manim)
#   Downloading pyglet-2.1.14-py3-none-any.whl.metadata (7.7 kB)
# Collecting pyglm<3,>=2.7.0 (from moderngl-window>=2.0.0->manim)
#   Downloading pyglm-2.8.3-cp314-cp314-macosx_10_15_x86_64.whl.metadata (13 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.0.0->manim)
#   Using cached markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.0.0->manim)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting Cython (from screeninfo>=0.7.0->manim)
#   Using cached cython-3.2.5-cp39-abi3-macosx_10_9_x86_64.whl.metadata (7.1 kB)
# Collecting pyobjc-framework-Cocoa (from screeninfo>=0.7.0->manim)
#   Downloading pyobjc_framework_cocoa-12.2-cp314-cp314-macosx_10_15_universal2.whl.metadata (2.6 kB)
# Collecting pyobjc-core>=12.2 (from pyobjc-framework-Cocoa->screeninfo>=0.7.0->manim)
#   Downloading pyobjc_core-12.2-cp314-cp314-macosx_10_15_universal2.whl.metadata (2.8 kB)
# Downloading manim-0.20.1-py3-none-any.whl (652 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 652.1/652.1 kB 16.8 MB/s  0:00:00
# Downloading manimpango-0.6.1-cp314-cp314-macosx_10_15_x86_64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 22.4 MB/s  0:00:00 eta 0:00:01
# Downloading audioop_lts-0.2.2-cp313-abi3-macosx_10_13_x86_64.whl (27 kB)
# Downloading av-17.1.0-cp311-abi3-macosx_11_0_x86_64.whl (22.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.5/22.5 MB 7.0 MB/s  0:00:03m0:00:0100:01
# Using cached click-8.4.1-py3-none-any.whl (116 kB)
# Downloading cloup-3.1.0-py2.py3-none-any.whl (55 kB)
# Downloading isosurfaces-0.1.2-py3-none-any.whl (11 kB)
# Downloading mapbox_earcut-2.0.0-cp314-cp314-macosx_10_15_x86_64.whl (55 kB)
# Downloading moderngl_window-3.1.1-py3-none-any.whl (382 kB)
# Downloading pyglm-2.8.3-cp314-cp314-macosx_10_15_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 4.8 MB/s  0:00:00 eta 0:00:01
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Downloading pillow-12.2.0-cp314-cp314-macosx_10_15_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 5.2 MB/s  0:00:01m0:00:0100:01
# Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading pyglet-2.1.14-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 5.1 MB/s  0:00:00
# Using cached rich-15.0.0-py3-none-any.whl (310 kB)
# Using cached markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading scipy-1.17.1-cp314-cp314-macosx_14_0_x86_64.whl (22.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.7/22.7 MB 5.9 MB/s  0:00:03 eta 0:00:01
# Downloading screeninfo-0.8.1-py3-none-any.whl (12 kB)
# Downloading skia_pathops-0.9.2-cp310-abi3-macosx_10_9_universal2.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 6.5 MB/s  0:00:00 eta 0:00:01
# Downloading svgelements-1.9.6-py2.py3-none-any.whl (137 kB)
# Downloading tqdm-4.68.2-py3-none-any.whl (78 kB)
# Using cached cython-3.2.5-cp39-abi3-macosx_10_9_x86_64.whl (2.9 MB)
# Downloading pyobjc_framework_cocoa-12.2-cp314-cp314-macosx_10_15_universal2.whl (388 kB)
# Downloading pyobjc_core-12.2-cp314-cp314-macosx_10_15_universal2.whl (6.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 6.8 MB/s  0:00:00 eta 0:00:01
# Building wheels for collected packages: moderngl, pycairo, glcontext, srt, watchdog
#   Building wheel for moderngl (pyproject.toml) ... done
#   Created wheel for moderngl: filename=moderngl-5.12.0-cp314-cp314-macosx_15_0_x86_64.whl size=111785 sha256=9e4a57b61327cff6075cf62164e43de0707e7d3da972b3d6da82e13ee650f49b
#   Stored in directory: /Users/ewan/Library/Caches/pip/wheels/ae/f7/05/d5828e23a0c31b14c40360bd98740b88e02f9042aca4320d99
#   Building wheel for pycairo (pyproject.toml) ... done
#   Created wheel for pycairo: filename=pycairo-1.29.0-cp314-cp314-macosx_15_0_x86_64.whl size=112486 sha256=f3c6abcc97caa9b5e62f390ac058121d8649b3a1cfaa88a8b9901a609c6a3e29
#   Stored in directory: /Users/ewan/Library/Caches/pip/wheels/16/c7/41/5b1f0a8f2bd8ddb889179e84bc344d858a82f496bcce245258
#   Building wheel for glcontext (pyproject.toml) ... done
#   Created wheel for glcontext: filename=glcontext-3.0.0-cp314-cp314-macosx_15_0_x86_64.whl size=9221 sha256=07b06e456ec06f730b52308ada6f1c76f8be7c9948f0bc2b2da57a63235b9433
#   Stored in directory: /Users/ewan/Library/Caches/pip/wheels/30/c2/09/a42f2605cc96193b38e494f4e05550ad395b3101fcd9254c94
#   Building wheel for srt (pyproject.toml) ... done
#   Created wheel for srt: filename=srt-3.5.3-py3-none-any.whl size=22511 sha256=76074972a8ce052f54a1aa2ed2d7f53d761ed39fab4a3a8043b30c2c8cbc8b86
#   Stored in directory: /Users/ewan/Library/Caches/pip/wheels/86/92/fd/8078b899ab1c6a806c9e45e8fa431fe6b191d747df9df838c6
#   Building wheel for watchdog (pyproject.toml) ... done
#   Created wheel for watchdog: filename=watchdog-6.0.0-cp314-cp314-macosx_15_0_x86_64.whl size=88216 sha256=1530f8c14f2606ec1b8329221578ef1aba69b870211a67d70bec47874ee6c51b
#   Stored in directory: /Users/ewan/Library/Caches/pip/wheels/0a/c0/14/73fceb17faf81aaac117630a4269363e2d9defb72ef5f6b0e7
# Successfully built moderngl pycairo glcontext srt watchdog
# Installing collected packages: svgelements, pyglm, pydub, glcontext, watchdog, tqdm, srt, skia-pathops, scipy, pyobjc-core, pyglet, pycairo, pillow, networkx, moderngl, mdurl, mapbox-earcut, manimpango, isosurfaces, Cython, click, av, audioop-lts, pyobjc-framework-Cocoa, moderngl-window, markdown-it-py, cloup, screeninfo, rich, manim
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30/30 [manim]m29/30 [manim]info]-py]]-Cocoa]
# Successfully installed Cython-3.2.5 audioop-lts-0.2.2 av-17.1.0 click-8.4.1 cloup-3.1.0 glcontext-3.0.0 isosurfaces-0.1.2 manim-0.20.1 manimpango-0.6.1 mapbox-earcut-2.0.0 markdown-it-py-4.2.0 mdurl-0.1.2 moderngl-5.12.0 moderngl-window-3.1.1 networkx-3.6.1 pillow-12.2.0 pycairo-1.29.0 pydub-0.25.1 pyglet-2.1.14 pyglm-2.8.3 pyobjc-core-12.2 pyobjc-framework-Cocoa-12.2 rich-15.0.0 scipy-1.17.1 screeninfo-0.8.1 skia-pathops-0.9.2 srt-3.5.3 svgelements-1.9.6 tqdm-4.68.2 watchdog-6.0.0
#
# [notice] A new release of pip is available: 26.0 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
from manim import *

# %%
# %%manim -qm -v WARNING SquareToCircle
#
# # class SquareToCircle(Scene):
# #    def construct(self):
# #       square = Square()
# #       circle = Circle()
# #       circle.set_fill(YELLOW, opacity=0.5)
# #       self.play(Create(square))
# #       self.play(Transform(square, circle))
# #       self.wait()
#
#
#
#
# # from manim import *
#
# class PointMovingOnShapes(Scene):
#     def construct(self):
#         circle = Circle(radius=1, color=BLUE)
#         dot = Dot()
#         dot2 = dot.copy().shift(RIGHT)
#         self.add(dot)
#
#         line = Line([3, 0, 0], [5, 0, 0])
#         self.add(line)
#
#         self.play(GrowFromCenter(circle))
#         self.play(Transform(dot, dot2))
#         self.play(MoveAlongPath(dot, circle), run_time=2, rate_func=linear)
#         self.play(Rotating(dot, about_point=[2, 0, 0]), run_time=1.5)
#         self.wait()
# Out:
# Manim Community v0.20.1
# <video src="media/jupyter/SquareToCircle@2026-06-16@05-38-43.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>
